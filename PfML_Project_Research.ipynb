# %% [markdown]
# <a href="https://colab.research.google.com/github/jako323/Most-Streamed-Songs-with-Python-Machine-Learning/blob/data_visualization/PfML_Project_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This google colab document will help us conduct a research about:
# **"What is the best set of small tweaks of adjustable parameters for specific song to improve number of spotify streams?"**

# %% [markdown]
# Firtsly, let us add dataset to this document.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/AGH/PythonForMLGoogleColab/spotify-2023.csv', encoding='latin')

# %%
data.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
data.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    952.000000     952.000000      952.000000    952.000000
# mean       1.556723    2018.288866        6.038866     13.944328
# std        0.893331      11.011397        3.564571      9.197223
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  \
# count            952.000000         952.000000  9.520000e+02
# mean            5202.565126          12.022059  5.141374e+08
# std             7901.400683          19.582405  5.668569e+08
# min               31.000000           0.000000  2.762000e+03
# 25%              874.500000           0.000000  1.416362e+08
# ...

# %% [markdown]
# **"What is the best set of small tweaks of adjustable parameters for specific song to improve number of spotify streams?"**

# %% [markdown]
# We understand that algorithm giving answer to this question would get as an input set of parameters that are "adjustable" for an artist and return as an output difference between streams as they are now and streams that could happen if... [for this part we need to find solution] What is more, we need to set reasonable boundaries for each of parameters that will be analyzed, so our algorithm would not change the whole characteristic of a given song.

# %% [markdown]
# This is a list of all parameters from this dataset:
#
#
# *   track_name
# *   artist(s)_name
# *   artist_count
# *   released_year
# *   released_month
# *   released_day
# *   in_spotify_playlists
# *   in_spotify_charts
# *   streams
# *   in_apple_playlists
# *   in_apple_charts
# *   in_deezer_playlists
# *   in_deezer_charts
# *   in_shazam_charts
# *   bpm
# *   key
# *   mode
# *   danceability_%
# *   valence_%
# *   energy_%
# *   acousticness_%
# *   instrumentalness_%
# *   liveness_%
# *   speechiness_%

# %% [markdown]
# **Input parameters**

# %% [markdown]
# List of input parameters that could have been modified by an author of particular song:
# *   released_day
# *   bpm
# *   key
# *   mode
# *   danceability_%
# *   valence_%
# *   energy_%
# *   acousticness_%
# *   instrumentalness_%
# *   liveness_%
# *   speechiness_%

# %% [markdown]
# **Output Parameters**

# %% [markdown]
# And for the outputs parameters listed below measure success (or failure) of specific song:
# *   in_spotify_playlists
# *   in_spotify_charts
# *   streams
# *   in_apple_playlists
# *   in_apple_charts
# *   in_deezer_playlists
# *   in_deezer_charts
# *   in_shazam_charts
#
# Based on intersting characteristics (large numbers) of parameter: **streams** we would like to use it as output for our algorithm.

# %% [markdown]
# **DATA VISUALIZATION**

# %% [markdown]
# **Input**

# %% [markdown]
# Firstly, delete unnecessary parameters

# %%
input_dataset = data.drop(['track_name',
                         'artist(s)_name',
                         'artist_count',
                         'released_year',
                         'released_month',
                         'in_spotify_playlists',
                         'in_spotify_charts',
                         'streams',
                         'in_apple_playlists',
                         'in_apple_charts',
                         'in_deezer_playlists',
                         'in_deezer_charts',
                         'in_shazam_charts',], axis=1)


input_dataset.head()
# Out:
#    released_day  bpm key   mode  danceability_%  valence_%  energy_%  \
# 0            14  125   B  Major              80         89        83
# 1            23   92  C#  Major              71         61        74
# 2            30  138   F  Major              51         32        53
# 3            23  170   A  Major              55         58        72
# 4            18  144   A  Minor              65         23        80
#
#    acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0              31                   0           8              4
# 1               7                   0          10              4
# 2              17                   0          31              6
# 3              11                   0          11             15
# 4              14                  63          11              6

# %% [markdown]
# And display heatmap of inputs

# %%
from sklearn.preprocessing import LabelEncoder, LabelBinarizer

le = LabelEncoder()
le.fit(input_dataset['key'])
input_dataset['key'] = le.transform(input_dataset['key'])

lb = LabelBinarizer()
lb.fit(input_dataset['mode'])
input_dataset['mode'] = lb.transform(input_dataset['mode'])


input_dataset.head()
# Out:
#    released_day  bpm  key  mode  danceability_%  valence_%  energy_%  \
# 0            14  125    2     0              80         89        83
# 1            23   92    3     0              71         61        74
# 2            30  138    7     0              51         32        53
# 3            23  170    0     0              55         58        72
# 4            18  144    0     1              65         23        80
#
#    acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0              31                   0           8              4
# 1               7                   0          10              4
# 2              17                   0          31              6
# 3              11                   0          11             15
# 4              14                  63          11              6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = input_dataset.corr()
plt.figure(figsize=(9,9))
sns.heatmap(corr, square=True, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# As we can see, for choosen parameters can be observed stronger correlations for:
#
# *   (!) danceability - valence
# *   danceability - energy
# *   danceability - acousticness
# *   (!) valence - energy
# *   (!) energy - acousticness
#
# Because of that we get rid of:
# *   valene
# *   energy

# %%
input_dataset = input_dataset.drop(['valence_%',
                                     'energy_%'], axis=1)


input_dataset.head()
# Out:
#    released_day  bpm  key  mode  danceability_%  acousticness_%  \
# 0            14  125    2     0              80              31
# 1            23   92    3     0              71               7
# 2            30  138    7     0              51              17
# 3            23  170    0     0              55              11
# 4            18  144    0     1              65              14
#
#    instrumentalness_%  liveness_%  speechiness_%
# 0                   0           8              4
# 1                   0          10              4
# 2                   0          31              6
# 3                   0          11             15
# 4                  63          11              6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = input_dataset.corr()
plt.figure(figsize=(9,9))
sns.heatmap(corr, square=True, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Final set of choosen input parameters**

# %% [markdown]
# *   released_day
# *   bpm
# *   key
# *   mode
# *   danceability_%
# *   acousticness_%
# *   instrumentalness_%
# *   liveness_%
# *   speechiness_%

# %% [markdown]
# **Output**

# %%
output_dataset = data.drop(['track_name',
                         'artist(s)_name',
                         'artist_count',
                         'released_year',
                         'released_month',
                         'released_day',
                         'bpm',
                         'key',
                         'mode',
                         'danceability_%',
                         'valence_%',
                         'energy_%',
                         'acousticness_%',
                         'instrumentalness_%',
                         'liveness_%',
                         'speechiness_%'], axis=1)


output_dataset.head()
# Out:
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
#
#    in_apple_charts in_deezer_playlists  in_deezer_charts in_shazam_charts
# 0              263                  45                10              826
# 1              126                  58                14              382
# 2              207                  91                14              949
# 3              207                 125                12              548
# 4              133                  87                15              425

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_spotify_playlists'], vert=False)
plt.xlabel('Number of in spotify playlists')
# Out:
# Text(0.5, 0, 'Number of in spotify playlists')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_spotify_charts'], vert=False)
plt.xlabel('Number of in spotify charts')
# Out:
# Text(0.5, 0, 'Number of in spotify charts')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['streams'], vert=False)
plt.xlabel('Number of streams')
# Out:
# Text(0.5, 0, 'Number of streams')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_apple_playlists'], vert=False)
plt.title('Violinplot for song\'s number of streams')
plt.xlabel('Number of in apple playlist')
# Out:
# Text(0.5, 0, 'Number of in apple playlist')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_apple_charts'], vert=False)
plt.title('Violinplot for song\'s number of streams')
plt.xlabel('Number of in apple charts')
# Out:
# Text(0.5, 0, 'Number of in apple charts')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_deezer_playlists'], vert=False)
plt.title('Violinplot for song\'s number of streams')
plt.xlabel('Number of streams')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-48-83f332a47d8e> in <cell line: 4>()
#       2
#       3 plt.figure(figsize=(10,5))
# ----> 4 plt.violinplot(output_dataset['in_deezer_playlists'], vert=False)
#       5 plt.title('Violinplot for song\'s number of streams')
#       6 plt.xlabel('Number of streams')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in violinplot(dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method, data)
#    3043         showmeans=False, showextrema=True, showmedians=False,
#    3044         quantiles=None, points=100, bw_method=None, *, data=None):
# -> 3045     return gca().violinplot(
#    3046         dataset, positions=positions, vert=vert, widths=widths,
#    3047         showmeans=showmeans, showextrema=showextrema,
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_deezer_charts'], vert=False)
plt.title('Violinplot for song\'s number of streams')
plt.xlabel('Number of streams')
# Out:
# Text(0.5, 0, 'Number of streams')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.violinplot(output_dataset['in_shazam_charts'], vert=False)
plt.title('Violinplot for song\'s number of streams')
plt.xlabel('Number of streams')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-353f72ff1885> in <cell line: 4>()
#       2
#       3 plt.figure(figsize=(10,5))
# ----> 4 plt.violinplot(output_dataset['in_shazam_charts'], vert=False)
#       5 plt.title('Violinplot for song\'s number of streams')
#       6 plt.xlabel('Number of streams')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in violinplot(dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method, data)
#    3043         showmeans=False, showextrema=True, showmedians=False,
#    3044         quantiles=None, points=100, bw_method=None, *, data=None):
# -> 3045     return gca().violinplot(
#    3046         dataset, positions=positions, vert=vert, widths=widths,
#    3047         showmeans=showmeans, showextrema=showextrema,
#
# ...

# %% [markdown]
# **HOW IT SHOULD WORK?**

# %% [markdown]
# We think that we can train our model so it can find best absolute inputs' values to maximize "streams" parameters. But, if we want to use it as a small advisor that can tell what minor changes should have been done in the past so now we could have a better outcome, we need to create artificial borders for algorithm movement. It will stil be working on the same surface, but it will be narrowed only to small chunk that is interesting to us in particular situation.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Remember for future: check if task narrowed by these borders is not too trivial - maybe a simple grid search would be good enough.
